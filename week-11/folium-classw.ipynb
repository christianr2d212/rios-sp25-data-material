# %%
import folium
import pandas as pd

# %%
utah_df= pd.read_csv("1871-utah-postmaster-salaries.csv")
print(utah_df.sample(5))


utah_df.dtypes
# Out:
#           PO_Name      County State  PM_Salary   Latitude   Longitude
# 113  Spanish Fork        Utah    UT         77  40.112733 -111.654645
# 78         Moroni     Sanpete    UT         92  39.524962 -111.584639
# 37       Franklin       Cache    UT         40  42.016111 -111.803056
# 62          Leeds  Washington    UT         12  37.238593 -113.359117
# 123         Union   Salt Lake    UT         44  40.606892 -111.874379
# PO_Name       object
# County        object
# State         object
# PM_Salary      int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
utah_map_empty = folium.Map(location=[40, -111], zoom_start=6)
utah_map_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fefdd6de18ccdc381c4bacac02225f5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fefdd6de18ccdc381c4bacac02225f5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fefdd6de18ccdc381c4bacac02225f5d = L.map(
#                 &quot;map_fefdd6de18ccdc381c4bacac02225f5d&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afdd242ebe86660eb38f1eac7945f3c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afdd242ebe86660eb38f1eac7945f3c7.addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Creating a Reusable Function for Maps

# %%
def create_empty_map():
    return folium.Map(location=[40, -111], zoom_start=6) ## this is utah map change location if copying code

utah_map = create_empty_map()
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee38e824fc6046e7805e599c1633b6d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee38e824fc6046e7805e599c1633b6d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee38e824fc6046e7805e599c1633b6d5 = L.map(
#                 &quot;map_ee38e824fc6046e7805e599c1633b6d5&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee69ade63a1aaeda2a7dd610faa13eff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee69ade63a1aaeda2a7dd610faa13eff.addTo(map_ee38e824fc6046e7805e599c1633b6d5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Check for columns with missing values
missing_values = utah_df.isna().sum()
print(missing_values)
# Out:
# PO_Name      0
# County       0
# State        0
# PM_Salary    0
# Latitude     4
# Longitude    4
# dtype: int64

# %%
utah_df_locations = utah_df[utah_df['Latitude'].notna()]

print(len(utah_df))
print(len(utah_df_locations))
# Out:
# 136
# 132

# %%
folium.Marker(location=[38.41, -112.339], popup="Adamsville Post Office").add_to(utah_map)
utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee38e824fc6046e7805e599c1633b6d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee38e824fc6046e7805e599c1633b6d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee38e824fc6046e7805e599c1633b6d5 = L.map(
#                 &quot;map_ee38e824fc6046e7805e599c1633b6d5&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee69ade63a1aaeda2a7dd610faa13eff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee69ade63a1aaeda2a7dd610faa13eff.addTo(map_ee38e824fc6046e7805e599c1633b6d5);
#
#
#             tile_layer_ee69ade63a1aaeda2a7dd610faa13eff.addTo(map_ee38e824fc6046e7805e599c1633b6d5);
#
#
#             var marker_d3f165bcad28abddbb487a3e2dfa2687 = L.marker(
#                 [38.41, -112.339],
#                 {
# }
#             ).addTo(map_ee38e824fc6046e7805e599c1633b6d5);
#
#
#         var popup_1c1cd2488eb725bd65d5c9ba338f5da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cef46ef856dda627035fe31cd251f289 = $(`&lt;div id=&quot;html_cef46ef856dda627035fe31cd251f289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville Post Office&lt;/div&gt;`)[0];
#                 popup_1c1cd2488eb725bd65d5c9ba338f5da4.setContent(html_cef46ef856dda627035fe31cd251f289);
#
#
#
#         marker_d3f165bcad28abddbb487a3e2dfa2687.bindPopup(popup_1c1cd2488eb725bd65d5c9ba338f5da4)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Melanie Walsh function we will adadpt to our dataset:
# def create_map_markers(row, map_name):
#    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

def create_map_markers(row, map_name):
    folium.Marker(location=[row['Latitude'], row['Longitude']], popup=row['Type']).add_to(map_name)

# %%
#create a base empty map
utah_map = create_empty_map()

#generate a random row of data
sample_row = utah_df_locations.sample(1)

#use our function on the random row
create_map_markers(sample_row, utah_map)

#display the map
utah_map
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:101: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:107: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /opt/anaconda3/lib/python3.12/site-packages/folium/utilities.py:109: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56eb5803c13a8bffe443e03e607918c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56eb5803c13a8bffe443e03e607918c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56eb5803c13a8bffe443e03e607918c3 = L.map(
#                 &quot;map_56eb5803c13a8bffe443e03e607918c3&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2ca7de96fe3b0ab27ef492431986d74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2ca7de96fe3b0ab27ef492431986d74.addTo(map_56eb5803c13a8bffe443e03e607918c3);
#
#
#             var marker_9a0e091048cf67f1f2cd2dc80d39649e = L.marker(
#                 [40.5318887, -112.2988357],
#                 {
# }
#             ).addTo(map_56eb5803c13a8bffe443e03e607918c3);
#
#
#         var popup_1ff281eec62579cca4040d3d332598b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75eec1c69ff1174598e638439042faab = $(`&lt;div id=&quot;html_75eec1c69ff1174598e638439042faab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;121    Tooele Name: PO_Name, dtype: object&lt;/div&gt;`)[0];
#                 popup_1ff281eec62579cca4040d3d332598b7.setContent(html_75eec1c69ff1174598e638439042faab);
#
#
#
#         marker_9a0e091048cf67f1f2cd2dc80d39649e.bindPopup(popup_1ff281eec62579cca4040d3d332598b7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Method 1: Using a for loop to iterate through our dataframe and add markers sequentially
# initialize an empty map
utah_map = create_empty_map()

# iterrows() allows you to loop through a dataframe row by row and return the index position + the row
for index, row in utah_df_locations.iterrows():
    print(f"Name of post office:", row[0])

#now let's iterate through and call our function for each row
for index, row in utah_df_locations.iterrows():
    create_map_markers(row, utah_map)

utah_map
# Out:
# Name of post office: Adamsville
# Name of post office: Alma
# Name of post office: Alpine City
# Name of post office: American Fork
# Name of post office: Bellevue
# Name of post office: Bingham Canyon
# Name of post office: Brigham City
# Name of post office: Bullion
# Name of post office: Cedar City
# Name of post office: Cedar Valley
# Name of post office: Centerville
# Name of post office: Central City
# Name of post office: Chicken Creek
# Name of post office: Clarkston
# Name of post office: Clifton
# Name of post office: Clover Valley
# Name of post office: Coalville
# Name of post office: Corinne
# Name of post office: Cove Creek
# Name of post office: Croydon
# Name of post office: Deseret
# Name of post office: Diamond
# Name of post office: Draper
# Name of post office: Duncans Retreat
# Name of post office: Echo City
# Name of post office: Eden
# Name of post office: Emmaville
# Name of post office: Ephraim
# Name of post office: Eureka
# Name of post office: Fair View
# Name of post office: Fairfield
# Name of post office: Farmington
# Name of post office: Fillmore City
# Name of post office: Forest City
# Name of post office: Fort Hamblin
# Name of post office: Fountain Green
# Name of post office: Franklin
# Name of post office: Goshen
# Name of post office: Grafton
# Name of post office: Grantsville
# Name of post office: Gunnison
# Name of post office: Harrisburg
# Name of post office: Harrisville
# Name of post office: Heber
# Name of post office: Hebron
# Name of post office: Herriman
# Name of post office: Holden
# Name of post office: Hooper
# Name of post office: Huntsville
# Name of post office: Hyde Park
# Name of post office: Hyrum
# Name of post office: Iron City
# Name of post office: Johnson
# Name of post office: Kamas
# Name of post office: Kanab
# Name of post office: Kanarraville
# Name of post office: Kanosh
# Name of post office: Kaysville
# Name of post office: Kelton
# Name of post office: Lake Point
# Name of post office: Leeds
# Name of post office: Lehi City
# Name of post office: Levan
# Name of post office: Liberty
# Name of post office: Logan
# Name of post office: Lynne
# Name of post office: Manti
# Name of post office: Meadow
# Name of post office: Mendon
# Name of post office: Midway
# Name of post office: Mill Creek
# Name of post office: Millville
# Name of post office: Minersville
# Name of post office: Mona
# Name of post office: Monroe
# Name of post office: Morgan
# Name of post office: Moroni
# Name of post office: New Harmony
# Name of post office: Newton
# Name of post office: North Ogden
# Name of post office: Ogden City
# Name of post office: Ophir
# Name of post office: Paradise
# Name of post office: Paragonah
# Name of post office: Parowan
# Name of post office: Payson
# Name of post office: Peoa
# Name of post office: Petersburgh
# Name of post office: Peterson
# Name of post office: Pine Valley
# Name of post office: Pinto
# Name of post office: Plain City
# Name of post office: Pleasant Grove
# Name of post office: Portage
# Name of post office: Providence
# Name of post office: Provo City
# Name of post office: Richfield
# Name of post office: Richmond
# Name of post office: Riverdale
# Name of post office: Rockville
# Name of post office: Saint George
# Name of post office: Salina
# Name of post office: Salt Creek
# Name of post office: Salt Lake City
# Name of post office: Santaquin
# Name of post office: Scipio
# Name of post office: Silver City
# Name of post office: Slatersville
# Name of post office: Smithfield
# Name of post office: South Cottonwood
# Name of post office: Spanish Fork
# Name of post office: Spring City
# Name of post office: Springdale
# Name of post office: Springville
# Name of post office: Stockton
# Name of post office: Stoker
# Name of post office: Summit
# Name of post office: Tokersville
# Name of post office: Tooele
# Name of post office: Uintah
# Name of post office: Union
# Name of post office: Virgin City
# Name of post office: Wales
# Name of post office: Wallsburg
# Name of post office: Wanship
# Name of post office: Wasatch
# Name of post office: Washington
# Name of post office: Wellsville
# Name of post office: West Jordan
# Name of post office: Willard
# Name of post office: Winsor
# Name of post office: Woods Cross
# /var/folders/9n/gp925nr113qgy0k5zrctqkcm0000gn/T/ipykernel_15589/2508161898.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Name of post office:", row[0])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69f715d31f55c79eb75751491523455e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69f715d31f55c79eb75751491523455e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69f715d31f55c79eb75751491523455e = L.map(
#                 &quot;map_69f715d31f55c79eb75751491523455e&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ffcbfd34ab2a9205159f410f3f35fd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ffcbfd34ab2a9205159f410f3f35fd7.addTo(map_69f715d31f55c79eb75751491523455e);
#
#
#             var marker_7e662e8cd00c7197a0a43a030f2456ec = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_69f715d31f55c79eb75751491523455e);
#
#
#         var popup_d0b3e24725dc5212c6ec721ed53e6506 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6647d4f8aa4cf3018eef463d89a5e8a = $(`&lt;div id=&quot;html_c6647d4f8aa4cf3018eef463d89a5e8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_d0b3e24725dc5212c6ec721ed53e6506.setContent(html_c6647d4f8aa4cf3018eef463d89a5e8a);
#
#
#
#         marker_7e662e8cd00c7197a0a43a030f2456ec.bindPopup(popup_d0b3e24725dc5212c6ec721ed53e6506)
#         ;
#
#
#
#
#             var marker_d0869a3c71fc73df520c86687179692d = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_69f715d31f55c79eb75751491523455e);
#
#
#         var popup_230596ebe753faa7b8e24575be0b9291 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a522476482c73dc67176f2a41f3053e1 = $(`&lt;div id=&quot;html_a522476482c73dc67176f2a41f3053e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_230596ebe753faa7b8e24575be0b9291.setContent(html_a522476482c73dc67176f2a41f3053e1);
#
#
#
#         marker_d0869a3c71fc73df520c86687179692d.bindPopup(popup_230596ebe753faa7b8e24575be0b9291)
#         ;
#
#
#
#
#             var marker_fb201dc9351edf18b0c1e8f580f24ca6 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_69f715d31f55c79eb75751491523455e);
#
#
#         var popup_2c3b473c5329eeca24f9de3cfd3809ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29d3831769b8349ec59a56ecc8247954 = $(`&lt;div id=&quot;html_29d3831769b8349ec59a56ecc8247954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_2c3b473c5329eeca24f9de3cfd3809ee.setContent(html_29d3831769b8349ec59a56ecc8247954);
#
#
#
#         marker_fb201dc9351edf18b0c1e8f580f24ca6.bindPopup(popup_2c3b473c5329eeca24f9de3cfd3809ee)
#         ;
#
#
#
#
#             var marker_512f8b935ad33a20868546e842ddf6a5 = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_69f715d31f55c79eb75751491523455e);
#
#
#         var popup_e7c1bf0240edd4165f5c14c68344dbdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef5a090ad254f41375875618505e4440 = $(`&lt;div id=&quot;html_ef5a090ad254f41375875618505e4440&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_e7c1bf0240edd4165f5c14c68344dbdf.setContent(html_ef5a090ad254f41375875618505e4440);
#
#
#
#         marker_512f8b935ad33a20868546e842ddf6a5.bindPopup(popup_e7c1bf0240edd4165f5c14c68344dbdf)
#         ;
#
#
#
#
#             var marker_9d94a6af3d2fe61ef8bccb395ab3e08a = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_69f715d31f55c79eb75751491523455e);
#
#
#         var popup_c13ef5beb32c263e7fc110dfa910b240 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfcc3554bd08642ff229292ae45cfd07 = $(`&lt;div id=&quot;html_cfcc3554bd08642ff229292ae45cfd07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_c13ef5beb32c263e7fc110dfa910b240.setContent(html_cfcc3554bd08642ff229292ae45cfd07);
#
#
#
#         marker_9d94a6af3d2fe61ef8bccb395ab3e08a.bindPopup(popup_c13ef5beb32c263e7fc110dfa910b240)
#         ;
#
#
#
#
#             var marker_d2e8ca2ec915de7b7cf28685d0276fa5 = L.marker(
#                 [40.5416128, -112.1479974],
#                 {
# }

# %%
# Method 2: Using .apply() to add markers with our function for all rows
# initialize an empty map
utah_map = utah_map_empty

# Now apply this function to each row in our filtered DataFrame
# For each row, we'll pass:
# 1. The row itself (handled automatically by .apply())
# 2. Our map object (we need to specify this explicitly)
# 3. The "axis" value for .apply() to indicate we want to process row by row
# .apply() allows you to apply a function to each row in the dataframe
utah_df_locations.apply(
    create_map_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fefdd6de18ccdc381c4bacac02225f5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fefdd6de18ccdc381c4bacac02225f5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fefdd6de18ccdc381c4bacac02225f5d = L.map(
#                 &quot;map_fefdd6de18ccdc381c4bacac02225f5d&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afdd242ebe86660eb38f1eac7945f3c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afdd242ebe86660eb38f1eac7945f3c7.addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#             tile_layer_afdd242ebe86660eb38f1eac7945f3c7.addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#             var marker_0a84515e15fbd360f9569e75fbd42e79 = L.marker(
#                 [38.2583031, -112.7938352],
#                 {
# }
#             ).addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#         var popup_3ca74c0ee45fc5327fb6e4b793b2f070 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f85013f0e8b7a191b2c6da0804553ddd = $(`&lt;div id=&quot;html_f85013f0e8b7a191b2c6da0804553ddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_3ca74c0ee45fc5327fb6e4b793b2f070.setContent(html_f85013f0e8b7a191b2c6da0804553ddd);
#
#
#
#         marker_0a84515e15fbd360f9569e75fbd42e79.bindPopup(popup_3ca74c0ee45fc5327fb6e4b793b2f070)
#         ;
#
#
#
#
#             var marker_94ea54c5d85dacbd0624078d56146c83 = L.marker(
#                 [41.2488333, -112.0782749],
#                 {
# }
#             ).addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#         var popup_8927ec50d1b34381fa29207c24b09f61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_540e26241b0b2ae39bb7975059ca0959 = $(`&lt;div id=&quot;html_540e26241b0b2ae39bb7975059ca0959&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_8927ec50d1b34381fa29207c24b09f61.setContent(html_540e26241b0b2ae39bb7975059ca0959);
#
#
#
#         marker_94ea54c5d85dacbd0624078d56146c83.bindPopup(popup_8927ec50d1b34381fa29207c24b09f61)
#         ;
#
#
#
#
#             var marker_3253c733a6764e4bdd842919956b5141 = L.marker(
#                 [40.4532834, -111.7779865],
#                 {
# }
#             ).addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#         var popup_14dd24ef4c898b8a60db8088b8ed7b56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87230b038b8de6640e36466bb53da34e = $(`&lt;div id=&quot;html_87230b038b8de6640e36466bb53da34e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_14dd24ef4c898b8a60db8088b8ed7b56.setContent(html_87230b038b8de6640e36466bb53da34e);
#
#
#
#         marker_3253c733a6764e4bdd842919956b5141.bindPopup(popup_14dd24ef4c898b8a60db8088b8ed7b56)
#         ;
#
#
#
#
#             var marker_8cf4dead2940cddb57ff64ec4150331e = L.marker(
#                 [40.3752288, -111.7963201],
#                 {
# }
#             ).addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#         var popup_13d3fd86aee9b86d28ab88010398a1ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e1e31c6f551fccf2654dc58956fedd6 = $(`&lt;div id=&quot;html_7e1e31c6f551fccf2654dc58956fedd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American Fork&lt;/div&gt;`)[0];
#                 popup_13d3fd86aee9b86d28ab88010398a1ee.setContent(html_7e1e31c6f551fccf2654dc58956fedd6);
#
#
#
#         marker_8cf4dead2940cddb57ff64ec4150331e.bindPopup(popup_13d3fd86aee9b86d28ab88010398a1ee)
#         ;
#
#
#
#
#             var marker_b3ae803b3b28b6c84ee368512ffed847 = L.marker(
#                 [37.3408149, -113.2741158],
#                 {
# }
#             ).addTo(map_fefdd6de18ccdc381c4bacac02225f5d);
#
#
#         var popup_55728b62555259e1ca214d5d5cb56527 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_915573b41571622e6b9ff4b64fe6726b = $(`&lt;div id=&quot;html_915573b41571622e6b9ff4b64fe6726b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bellevue&lt;/div&gt;`)[0];
#                 popup_55728b62555259e1ca214d5d5cb56527.setContent(html_915573b41571622e6b9ff4b64fe6726b);
#
#
#
#         marker_b3ae803b3b28b6c84ee368512ffed847.bindPopup(popup_55728b62555259e1ca214d5d5cb56527)
#         ;
#
#
#
#
#             var

# %%
# Melanie Walsh function we will edit:
#def create_ICE_map_markers(row, map_name):
#    folium.CircleMarker(location=[row['lat'], row['lon']], raidus=100, fill=True,
#                       popup=folium.Popup(f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}", max_width=200),
#                       tooltip=f"{row['Name'].title()} <br> {row['City'].title()}, {row['State']}"
#                       ).add_to(map_name)

def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=1,
                       fill=True,
                       popup=folium.Popup(f"{row['PO_Name'].title()}", max_width=200),
                       tooltip=f"{row['PO_Name'].title()}"
                       ).add_to(map_name)

# %%
# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(create_circle_markers, map_name=utah_map, axis="columns")

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e62ff5189fff5756d18667ecabcaf389 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e62ff5189fff5756d18667ecabcaf389&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e62ff5189fff5756d18667ecabcaf389 = L.map(
#                 &quot;map_e62ff5189fff5756d18667ecabcaf389&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_981498005f7734e34f7f848b54820421 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_981498005f7734e34f7f848b54820421.addTo(map_e62ff5189fff5756d18667ecabcaf389);
#
#
#             var circle_marker_15084a822f5a14004ad7a804bcce4e55 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e62ff5189fff5756d18667ecabcaf389);
#
#
#         var popup_5d39160bae5ca97ca326c56871ba337d = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_9ca33fdebecb442d210d807317078f8c = $(`&lt;div id=&quot;html_9ca33fdebecb442d210d807317078f8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adamsville&lt;/div&gt;`)[0];
#                 popup_5d39160bae5ca97ca326c56871ba337d.setContent(html_9ca33fdebecb442d210d807317078f8c);
#
#
#
#         circle_marker_15084a822f5a14004ad7a804bcce4e55.bindPopup(popup_5d39160bae5ca97ca326c56871ba337d)
#         ;
#
#
#
#
#             circle_marker_15084a822f5a14004ad7a804bcce4e55.bindTooltip(
#                 `&lt;div&gt;
#                      Adamsville
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f792e0565831a54c46cf4e2eea8bb425 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e62ff5189fff5756d18667ecabcaf389);
#
#
#         var popup_6f3479a842f0efc959d3a610f0f62237 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_87d4ba39d62b371afffb600a951f0d5f = $(`&lt;div id=&quot;html_87d4ba39d62b371afffb600a951f0d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alma&lt;/div&gt;`)[0];
#                 popup_6f3479a842f0efc959d3a610f0f62237.setContent(html_87d4ba39d62b371afffb600a951f0d5f);
#
#
#
#         circle_marker_f792e0565831a54c46cf4e2eea8bb425.bindPopup(popup_6f3479a842f0efc959d3a610f0f62237)
#         ;
#
#
#
#
#             circle_marker_f792e0565831a54c46cf4e2eea8bb425.bindTooltip(
#                 `&lt;div&gt;
#                      Alma
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6c23f9d3e1ac03511caf403a2f888fd4 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e62ff5189fff5756d18667ecabcaf389);
#
#
#         var popup_eb9158df47019c769e13622e7167d756 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4b499ddd536e735ca84c644f7e9746fc = $(`&lt;div id=&quot;html_4b499ddd536e735ca84c644f7e9746fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alpine City&lt;/div&gt;`)[0];
#                 popup_eb9158df47019c769e13622e7167d756.setContent(html_4b499ddd536e735ca84c644f7e9746fc);

# %%
# alter map appearance
def create_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=3,
                       color='lavender',
                       fill=True,
                       fill_color='red',
                       fill_opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb9715f3e5f02a11db687a13c3d7816d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb9715f3e5f02a11db687a13c3d7816d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb9715f3e5f02a11db687a13c3d7816d = L.map(
#                 &quot;map_bb9715f3e5f02a11db687a13c3d7816d&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_213e0248b1883693f2027bc448a242c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_213e0248b1883693f2027bc448a242c1.addTo(map_bb9715f3e5f02a11db687a13c3d7816d);
#
#
#             var circle_marker_cbd61403c142ccb30de6c48611482190 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;lavender&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bb9715f3e5f02a11db687a13c3d7816d);
#
#
#         var popup_bd1237d6aea9e134227a22e11575b539 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_a41567dfc3ea278fc0f0fd258de08428 = $(`&lt;div id=&quot;html_a41567dfc3ea278fc0f0fd258de08428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_bd1237d6aea9e134227a22e11575b539.setContent(html_a41567dfc3ea278fc0f0fd258de08428);
#
#
#
#         circle_marker_cbd61403c142ccb30de6c48611482190.bindPopup(popup_bd1237d6aea9e134227a22e11575b539)
#         ;
#
#
#
#
#             circle_marker_cbd61403c142ccb30de6c48611482190.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1f96657691705184c9331902eee3b85c = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;lavender&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bb9715f3e5f02a11db687a13c3d7816d);
#
#
#         var popup_6f9cbac23505b7b9186daacba2ad281c = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_53d5f199f2ff2d74d2c900070c154a00 = $(`&lt;div id=&quot;html_53d5f199f2ff2d74d2c900070c154a00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_6f9cbac23505b7b9186daacba2ad281c.setContent(html_53d5f199f2ff2d74d2c900070c154a00);
#
#
#
#         circle_marker_1f96657691705184c9331902eee3b85c.bindPopup(popup_6f9cbac23505b7b9186daacba2ad281c)
#         ;
#
#
#
#
#             circle_marker_1f96657691705184c9331902eee3b85c.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_375c0b283369d98ec7fcdc48cc24693f = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;lavender&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bb9715f3e5f02a11db687a13c3d7816d);
#
#
#         var popup_a57a1cf402c80cc7906efba634fab0c8 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c8dc6debd2db60e9d95a069db99d48df = $(`&lt;div id=&quot;html_c8dc6debd2db60e9d95a069db99d48df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_a57a1cf402c80cc7906efba634fab0c8.setContent(html

# %%
# make new function to create circle markers sized by postmaster salary
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary'],
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a807e36900ff57a54e207c5d7697dcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a807e36900ff57a54e207c5d7697dcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a807e36900ff57a54e207c5d7697dcb = L.map(
#                 &quot;map_9a807e36900ff57a54e207c5d7697dcb&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f446c222721fc41ae4c7604b0d4b338 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f446c222721fc41ae4c7604b0d4b338.addTo(map_9a807e36900ff57a54e207c5d7697dcb);
#
#
#             var circle_marker_751bc7177596b5e227dfcb8f61598a53 = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a807e36900ff57a54e207c5d7697dcb);
#
#
#         var popup_1868cb2e0ca9520254041bfa45cfc8c5 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_d62493b58a50c5d9119f339149dbd91a = $(`&lt;div id=&quot;html_d62493b58a50c5d9119f339149dbd91a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_1868cb2e0ca9520254041bfa45cfc8c5.setContent(html_d62493b58a50c5d9119f339149dbd91a);
#
#
#
#         circle_marker_751bc7177596b5e227dfcb8f61598a53.bindPopup(popup_1868cb2e0ca9520254041bfa45cfc8c5)
#         ;
#
#
#
#
#             circle_marker_751bc7177596b5e227dfcb8f61598a53.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_71c63bae1ab4cd99dba34df4a9f4a4fd = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a807e36900ff57a54e207c5d7697dcb);
#
#
#         var popup_bf5257bbb593ec03311f86e6987c36b1 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_c4d55eff6e37faed6bf288ca79abb157 = $(`&lt;div id=&quot;html_c4d55eff6e37faed6bf288ca79abb157&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_bf5257bbb593ec03311f86e6987c36b1.setContent(html_c4d55eff6e37faed6bf288ca79abb157);
#
#
#
#         circle_marker_71c63bae1ab4cd99dba34df4a9f4a4fd.bindPopup(popup_bf5257bbb593ec03311f86e6987c36b1)
#         ;
#
#
#
#
#             circle_marker_71c63bae1ab4cd99dba34df4a9f4a4fd.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_009a41fd02e47164ad42c4334e045e3c = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a807e36900ff57a54e207c5d7697dcb);
#
#
#         var popup_e20828a34e2ce3deb1471c5e76915e17 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_be2ab5448d7f266f408b5a57c8b17274 = $(`&lt;div id=&quot;html_be2ab5448d7f266f408b5a57c8b17274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_e20828a34e2ce3deb1471c5e76915e17.set

# %%
# make new function to create circle markers sized by postmaster salary - this time adjusting the radius size in pixels to make it more legible
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['PM_Salary']/100,
                       fill=True,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98fc0650317bfe71aea6481ed76a0432 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98fc0650317bfe71aea6481ed76a0432&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98fc0650317bfe71aea6481ed76a0432 = L.map(
#                 &quot;map_98fc0650317bfe71aea6481ed76a0432&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08de897b78787174e418b28c4861d4dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08de897b78787174e418b28c4861d4dc.addTo(map_98fc0650317bfe71aea6481ed76a0432);
#
#
#             var circle_marker_899fe714b8f45ccd968d9470b0eabe1e = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98fc0650317bfe71aea6481ed76a0432);
#
#
#         var popup_1e462dac3e793a985589bfc758a5b810 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f1afa441d1023d1ade39059aca94e0ba = $(`&lt;div id=&quot;html_f1afa441d1023d1ade39059aca94e0ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_1e462dac3e793a985589bfc758a5b810.setContent(html_f1afa441d1023d1ade39059aca94e0ba);
#
#
#
#         circle_marker_899fe714b8f45ccd968d9470b0eabe1e.bindPopup(popup_1e462dac3e793a985589bfc758a5b810)
#         ;
#
#
#
#
#             circle_marker_899fe714b8f45ccd968d9470b0eabe1e.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_9629b38504eedadb3f1d314c487dff08 = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98fc0650317bfe71aea6481ed76a0432);
#
#
#         var popup_49f4ea90d6f112c7ae8df02df4c0e56a = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_32cff426e7f0bbace81005b43e0a4ff1 = $(`&lt;div id=&quot;html_32cff426e7f0bbace81005b43e0a4ff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_49f4ea90d6f112c7ae8df02df4c0e56a.setContent(html_32cff426e7f0bbace81005b43e0a4ff1);
#
#
#
#         circle_marker_9629b38504eedadb3f1d314c487dff08.bindPopup(popup_49f4ea90d6f112c7ae8df02df4c0e56a)
#         ;
#
#
#
#
#             circle_marker_9629b38504eedadb3f1d314c487dff08.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c3b33991e8dad914c0f18c1c4c5f1989 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98fc0650317bfe71aea6481ed76a0432);
#
#
#         var popup_647dee395f4fed1c449249eddf0e4723 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_ca03ea7900e15b7c46e1487baab2c4a5 = $(`&lt;div id=&quot;html_ca03ea7900e15b7c46e1487baab2c4a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_647dee395f4fed1c449249eddf0e472

# %%
utah_df_locations.describe()
# Out:
#          PM_Salary    Latitude   Longitude
# count   132.000000  132.000000  132.000000
# mean    101.098485   39.907743 -112.161190
# std     344.225580    1.505091    0.593117
# min       4.000000   37.006375 -113.819415
# 25%      12.000000   38.874099 -112.379230
# 50%      22.000000   40.380926 -111.973830
# 75%      70.000000   41.080917 -111.819912
# max    3600.000000   42.187500 -111.281850

# %%
def add_salary_buckets(salary):
    # Create a new column for the salary bucket
    if salary < 50:
        bucket = 'Low Salary'
    elif salary >= 50 and salary < 250:
        bucket = 'Medium Salary'
    elif salary >= 250 and salary < 1000:
        bucket = 'High Salary'
    else:
        bucket = 'Very High Salary'
    return bucket

# %%
#test out the function
add_salary_buckets(2000)
# Out:
# 'Very High Salary'

# %%
utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
utah_df_locations.head()
# Out:
# /var/folders/9n/gp925nr113qgy0k5zrctqkcm0000gn/T/ipykernel_15589/2959544325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Salary_Bucket'] = utah_df_locations['PM_Salary'].apply(add_salary_buckets)
#          PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0     Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1           Alma       Weber    UT         12  41.248833 -112.078275
# 2    Alpine City        Utah    UT         27  40.453283 -111.777986
# 3  American Fork        Utah    UT        130  40.375229 -111.796320
# 4       Bellevue  Washington    UT         20  37.340815 -113.274116
#
#    Salary_Bucket
# 0     Low Salary
# 1     Low Salary
# 2     Low Salary
# 3  Medium Salary
# 4     Low Salary

# %%
# create a function to add marker sizes based on the salary bucket
def add_marker_sizes(category):
    if category == 'Low Salary':
        return 4
    elif category == 'Medium Salary':
        return 8
    elif category == 'High Salary':
        return 12
    else:
        return 16

#test out the function
add_marker_sizes('High Salary')
# Out:
# 12

# %%
utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
utah_df_locations.head(10)
# Out:
# /var/folders/9n/gp925nr113qgy0k5zrctqkcm0000gn/T/ipykernel_15589/3689819186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   utah_df_locations['Marker_Size'] = utah_df_locations['Salary_Bucket'].apply(add_marker_sizes)
#            PO_Name      County State  PM_Salary   Latitude   Longitude  \
# 0       Adamsville      Beaver    UT         10  38.258303 -112.793835
# 1             Alma       Weber    UT         12  41.248833 -112.078275
# 2      Alpine City        Utah    UT         27  40.453283 -111.777986
# 3    American Fork        Utah    UT        130  40.375229 -111.796320
# 4         Bellevue  Washington    UT         20  37.340815 -113.274116
# 5   Bingham Canyon   Salt Lake    UT         12  40.541613 -112.147997
# 7     Brigham City   Box Elder    UT        400  41.510213 -112.015501
# 8          Bullion       Piute    UT         12  38.410000 -112.339000
# 9       Cedar City        Iron    UT        200  37.676644 -113.057171
# 10    Cedar Valley        Utah    UT         13  40.327171 -112.104385
#
#     Salary_Bucket  Marker_Size
# 0      Low Salary            4
# 1      Low Salary            4
# 2      Low Salary            4
# 3   Medium Salary            8
# 4      Low Salary            4
# 5      Low Salary            4
# 7     High Salary           12
# 8      Low Salary            4
# 9   Medium Salary            8
# 10     Low Salary            4

# %%
# make new function to create circle markers sized by salary category
def create_sized_circle_markers(row, map_name):
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']],
                       radius=row['Marker_Size'],
                       fill=True,
                       opacity=0.6,
                       popup=folium.Popup(f"Post Office: {row['PO_Name'].title()}", max_width=200),
                       tooltip=f"Postmaster Salary: ${row['PM_Salary']}"
                       ).add_to(map_name)

# initialize an empty map
utah_map = create_empty_map()

# call our function for each row
utah_df_locations.apply(
    create_sized_circle_markers, # The function to apply
    map_name=utah_map, # Additional argument to pass to the function
    axis='columns' # Process row by row instead of column by column
)

utah_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1863a40f0d3b4a96c0450dec6ea47253 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1863a40f0d3b4a96c0450dec6ea47253&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1863a40f0d3b4a96c0450dec6ea47253 = L.map(
#                 &quot;map_1863a40f0d3b4a96c0450dec6ea47253&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e491976071c9e1ed22229e6f822d11f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e491976071c9e1ed22229e6f822d11f.addTo(map_1863a40f0d3b4a96c0450dec6ea47253);
#
#
#             var circle_marker_9e43bf9bf161698b49bfa00b41f6551f = L.circleMarker(
#                 [38.2583031, -112.7938352],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1863a40f0d3b4a96c0450dec6ea47253);
#
#
#         var popup_91041ca04b9c8ab62146ae54caa9a273 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_36f646656b9341f7bdef3d31dbbaac72 = $(`&lt;div id=&quot;html_36f646656b9341f7bdef3d31dbbaac72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Adamsville&lt;/div&gt;`)[0];
#                 popup_91041ca04b9c8ab62146ae54caa9a273.setContent(html_36f646656b9341f7bdef3d31dbbaac72);
#
#
#
#         circle_marker_9e43bf9bf161698b49bfa00b41f6551f.bindPopup(popup_91041ca04b9c8ab62146ae54caa9a273)
#         ;
#
#
#
#
#             circle_marker_9e43bf9bf161698b49bfa00b41f6551f.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6ca9b1cd8d000b07cefbe88c54648ede = L.circleMarker(
#                 [41.2488333, -112.0782749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1863a40f0d3b4a96c0450dec6ea47253);
#
#
#         var popup_bf903c0d70fb15ae62dcb2a1f780f128 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_b476057fec178fd0f504f55cf0fc18f6 = $(`&lt;div id=&quot;html_b476057fec178fd0f504f55cf0fc18f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alma&lt;/div&gt;`)[0];
#                 popup_bf903c0d70fb15ae62dcb2a1f780f128.setContent(html_b476057fec178fd0f504f55cf0fc18f6);
#
#
#
#         circle_marker_6ca9b1cd8d000b07cefbe88c54648ede.bindPopup(popup_bf903c0d70fb15ae62dcb2a1f780f128)
#         ;
#
#
#
#
#             circle_marker_6ca9b1cd8d000b07cefbe88c54648ede.bindTooltip(
#                 `&lt;div&gt;
#                      Postmaster Salary: $12
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_cc5e8ffb7326f44892ae073cd3ed72c8 = L.circleMarker(
#                 [40.4532834, -111.7779865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1863a40f0d3b4a96c0450dec6ea47253);
#
#
#         var popup_e745d56ca932aa1e63e1d5e13989ada6 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_7271bd15ce370a08e5d3b1488d91931a = $(`&lt;div id=&quot;html_7271bd15ce370a08e5d3b1488d91931a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Post Office: Alpine City&lt;/div&gt;`)[0];
#                 popup_e745d56ca932aa1e63e1d5e13989ada6.setCon

# %%
employee_df = pd.read_csv("1877-official-register.csv")

# %%
employee_df.sample(4)
# Out:
#                Name State      Department                                Type  \
# 452         Olympia    WA        Judicial                               Court
# 814     Camp Gaston    CA  War Department                             Outpost
# 382        Marshall    TX        Judicial                        Commissioner
# 765  Fort Fetterman    WY  War Department  Quartermasters Department At Large
#
#      People   Latitude   Longitude
# 452       5  47.037874 -122.900695
# 814      38  41.050278 -123.674167
# 382       3  32.544871  -94.367418
# 765       2  42.840278 -105.479722

# %%
missing_values= employee_df.isna().sum()
print(missing_values)
# Out:
# Name          0
# State         0
# Department    0
# Type          0
# People        0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
us_map = create_empty_map()
employee_df.apply(create_map_markers,
                 map_name=us_map,
                 axis='columns'
                 )

us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc1d3084a620b1ce048c63315fa1e78c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc1d3084a620b1ce048c63315fa1e78c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc1d3084a620b1ce048c63315fa1e78c = L.map(
#                 &quot;map_cc1d3084a620b1ce048c63315fa1e78c&quot;,
#                 {
#                     center: [40.0, -111.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d40fb049b9e9f04c1b0542539180701 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d40fb049b9e9f04c1b0542539180701.addTo(map_cc1d3084a620b1ce048c63315fa1e78c);
#
#
#             var marker_7c348124636be80b2ca9f3be2c048679 = L.marker(
#                 [34.5400242, -112.468503],
#                 {
# }
#             ).addTo(map_cc1d3084a620b1ce048c63315fa1e78c);
#
#
#         var popup_eb6c2723d03f833dcbe2da85b98e9dd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37bc6749c2bb0905061b6fdb376fe88e = $(`&lt;div id=&quot;html_37bc6749c2bb0905061b6fdb376fe88e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;General Land Office Receivers&lt;/div&gt;`)[0];
#                 popup_eb6c2723d03f833dcbe2da85b98e9dd5.setContent(html_37bc6749c2bb0905061b6fdb376fe88e);
#
#
#
#         marker_7c348124636be80b2ca9f3be2c048679.bindPopup(popup_eb6c2723d03f833dcbe2da85b98e9dd5)
#         ;
#
#
#
#
#             var marker_e44b5b3bb371494105b7384dc6f28882 = L.marker(
#                 [33.0314508, -111.387343],
#                 {
# }
#             ).addTo(map_cc1d3084a620b1ce048c63315fa1e78c);
#
#
#         var popup_e42a69a00a46709f12cc33010753d014 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b33f157bd42b77d7efd170ed48023c5a = $(`&lt;div id=&quot;html_b33f157bd42b77d7efd170ed48023c5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;General Land Office Receivers&lt;/div&gt;`)[0];
#                 popup_e42a69a00a46709f12cc33010753d014.setContent(html_b33f157bd42b77d7efd170ed48023c5a);
#
#
#
#         marker_e44b5b3bb371494105b7384dc6f28882.bindPopup(popup_e42a69a00a46709f12cc33010753d014)
#         ;
#
#
#
#
#             var marker_c7f1a603205f35584f4beb1a2345b8df = L.marker(
#                 [37.7749295, -122.419416],
#                 {
# }
#             ).addTo(map_cc1d3084a620b1ce048c63315fa1e78c);
#
#
#         var popup_d6bde90df356c1f9ee68ea00941064bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37ac15968c0b6e75a4165c40ee783cbd = $(`&lt;div id=&quot;html_37ac15968c0b6e75a4165c40ee783cbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;General Land Office Receivers&lt;/div&gt;`)[0];
#                 popup_d6bde90df356c1f9ee68ea00941064bf.setContent(html_37ac15968c0b6e75a4165c40ee783cbd);
#
#
#
#         marker_c7f1a603205f35584f4beb1a2345b8df.bindPopup(popup_d6bde90df356c1f9ee68ea00941064bf)
#         ;
#
#
#
#
#             var marker_5b5572b45315a811ab0d207fbd1db34b = L.marker(
#                 [39.1457253, -121.591355],
#                 {
# }
#             ).addTo(map_cc1d3084a620b1ce048c63315fa1e78c);
#
#
#         var popup_3fdcf20e9a42f5216f78820a9c67e682 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1adab38a1ad1cd216a1fe7f3f75bcccd = $(`&lt;div id=&quot;html_1adab38a1ad1cd216a1fe7f3f75bcccd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;General Land Office Receivers&lt;/div&gt;`)[0];
#                 popup_3fdcf20e9a42f5216f78820a9c67e682.setContent(html_1adab38a1ad1cd216a1fe7f3f75bcccd);
#
#
#
#         marker_5b5572b45315a811ab0d207fbd1db34b.bindPopup(popup_3fdcf20e9a42f5216f78820a9c67e682)
#         ;
#
#
#
#
#             var marker_04aa9cc1a8427b7bad31c4a30e9ef3b0 = L.marker(
#                 [40.7450055, -123.869509],
#                 {
# }
#             ).addTo(map_cc1d3084a620b1ce048c63315fa1e78c);
#
#
#         var popup_8e15cfc341fd231d5031ca0c814283aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ff9deeebe29e12404fa6534025c0122 = $(`&lt;div id=&quot;html_0ff9deeebe29e12404fa6534025c0122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;General Land Office Receivers&lt;/div&gt;`)[0];
#                 popup_8e15cfc341fd231d5031ca0c814283aa.setContent(html_0ff9deeebe29e12404fa6534025c0122);
#
#
#
#         marker_04aa9cc1a8427b7bad31c4a30e9ef3b0.bindPopup(popup_8e15cfc341fd231d5031ca0c814283aa)
#         ;
#
#
#
#
#             var marker_d44b28c68b4e80
