# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nobel_df = pd.read_csv("nobel_winners.csv")

# %%
nobel_df.sample(10)
nobel_df['gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 969 entries, 0 to 968
# Series name: gender
# Non-Null Count  Dtype
# --------------  -----
# 943 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
nobel_df.shape
# Out:
# (969, 18)

# %%
nobel_df.dtypes
# Out:
# prize_year               int64
# category                object
# prize                   object
# motivation              object
# prize_share             object
# laureate_id              int64
# laureate_type           object
# full_name               object
# birth_date              object
# birth_city              object
# birth_country           object
# gender                  object
# organization_name       object
# organization_city       object
# organization_country    object
# death_date              object
# death_city              object
# death_country           object
# dtype: object

# %%
nobel_df.describe(include='all')
# Out:
#          prize_year  category                                           prize  \
# count    969.000000       969                                             969
# unique          NaN         6                                             579
# top             NaN  Medicine  The Nobel Prize in Physiology or Medicine 2009
# freq            NaN       227                                               5
# mean    1970.287926       NaN                                             NaN
# std       32.937498       NaN                                             NaN
# min     1901.000000       NaN                                             NaN
# 25%     1947.000000       NaN                                             NaN
# 50%     1976.000000       NaN                                             NaN
# 75%     1999.000000       NaN                                             NaN
# max     2016.000000       NaN                                             NaN
#
# ...

# %%
women_filter = nobel_df['gender'] == 'Female'
male_filter = nobel_df['gender'] == 'Male'

women_df = nobel_df[women_filter]

# %%
nobel_df[nobel_df['gender'].isna()]
# Out:
#      prize_year category                       prize  \
# 24         1904    Peace  The Nobel Peace Prize 1904
# 61         1910    Peace  The Nobel Peace Prize 1910
# 90         1917    Peace  The Nobel Peace Prize 1917
# 206        1938    Peace  The Nobel Peace Prize 1938
# 222        1944    Peace  The Nobel Peace Prize 1944
# 244        1947    Peace  The Nobel Peace Prize 1947
# 245        1947    Peace  The Nobel Peace Prize 1947
# 295        1954    Peace  The Nobel Peace Prize 1954
# 365        1963    Peace  The Nobel Peace Prize 1963
# 366        1963    Peace  The Nobel Peace Prize 1963
# 383        1965    Peace  The Nobel Peace Prize 1965
# 416        1969    Peace  The Nobel Peace Prize 1969
# 498        1977    Peace  The Nobel Peace Prize 1977
# 543        1981    Peace  The Nobel Peace Prize 1981
# 578        1985    Peace  The Nobel Peace Prize 1985
# 610        1988    Peace  The Nobel Peace Prize 1988
# 682        1995    Peace  The Nobel Peace Prize 1995
# ...

# %%
nobel_df[women_filter]
# Out:
#      prize_year    category  \
# 19         1903     Physics
# 29         1905       Peace
# 52         1909  Literature
# 63         1911   Chemistry
# 129        1926  Literature
# 142        1928  Literature
# 163        1931       Peace
# 183        1935   Chemistry
# 204        1938  Literature
# 225        1945  Literature
# 236        1946       Peace
# 242        1947    Medicine
# 368        1963     Physics
# 370        1964   Chemistry
# 389        1966  Literature
# 486        1976       Peace
# 487        1976       Peace
# 497        1977    Medicine
# 520        1979       Peace
# 553        1982       Peace
# 559        1983    Medicine
# 586        1986    Medicine
# 608        1988    Medicine
# 637        1991  Literature
# 640        1991       Peace
# 647        1992       Peace
# 654        1993  Literature
# 679        1995    Medicine
# 690        1996  Literature
# 706        1997       Peace
# 781        2003       Peace
# 792        2004  Literature
# ...

# %%
nobel_df.groupby('gender').count()
# Out:
#         prize_year  category  prize  motivation  prize_share  laureate_id  \
# gender
# Female          50        50     50          43           50           50
# Male           893       893    893         828          893          893
#
#         laureate_type  full_name  birth_date  birth_city  birth_country  \
# gender
# Female             50         50          50          50             50
# Male              893        893         888         891            893
#
#         organization_name  organization_city  organization_country  \
# gender
# Female                 19                 19                    19
# Male                  703                697                   697
#
#         death_date  death_city  death_country
# gender
# Female          27          27             27
# Male           590         572            578

# %%
categories= women_df.groupby('prize_year').sum()

# %%
categories
# Out:
#                                                      category  \
# prize_year
# 1903                                                  Physics
# 1905                                                    Peace
# 1909                                               Literature
# 1911                                                Chemistry
# 1926                                               Literature
# 1928                                               Literature
# 1931                                                    Peace
# 1935                                                Chemistry
# 1938                                               Literature
# 1945                                               Literature
# 1946                                                    Peace
# 1947                                                 Medicine
# 1963                                                  Physics
# 1964                                                Chemistry
# ...
